# %% [markdown]
# # Analyzing Data

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Reading csv file (raw dataset)

# %%
dataset = pd.read_csv('finaldata.csv')
dataset.head()
# Out:
#       score      nose.x      nose.y  nose.score   leftEye.x   leftEye.y  \
# 0  0.442102  108.738780   47.988105    0.229462  111.893715   46.692416
# 1  0.063144  117.449880  102.737121    0.002066  113.653701  106.626447
# 2  0.034086  117.626733   45.139581    0.007047  188.052499   79.762799
# 3  0.494649  144.697880   71.559764    0.934364  148.007529   69.838149
# 4  0.008539  234.872977   16.636874    0.000705  162.790018    3.606339
#
#    leftEye.score  rightEye.x  rightEye.y  rightEye.score    ...     \
# 0       0.203802  109.049632   48.145040        0.106174    ...
# 1       0.004423  114.049373  107.309548        0.001751    ...
# 2       0.004122   91.939183   -4.568707        0.004513    ...
# 3       0.825449  139.243955   67.130005        0.914242    ...
# 4       0.000750   36.423653   88.531245        0.000910    ...
#
#    rightKnee.x  rightKnee.y  rightKnee.score  leftAnkle.x  leftAnkle.y  \
# ...

# %% [markdown]
# ## Converting 'shotType' to numeric Classes

# %%
dataset['shotType'] = pd.factorize(dataset['shotType'])[0] + 1

# %% [markdown]
# ## Some attributes of dataset

# %%
dataset.shape
# Out:
# (2242, 53)

# %%
dataset.columns
# Out:
# Index(['score', 'nose.x', 'nose.y', 'nose.score', 'leftEye.x', 'leftEye.y',
#        'leftEye.score', 'rightEye.x', 'rightEye.y', 'rightEye.score',
#        'leftEar.x', 'leftEar.y', 'leftEar.score', 'rightEar.x', 'rightEar.y',
#        'rightEar.score', 'leftShoulder.x', 'leftShoulder.y',
#        'leftShoulder.score', 'rightShoulder.x', 'rightShoulder.y',
#        'rightShoulder.score', 'leftElbow.x', 'leftElbow.y', 'leftElbow.score',
#        'rightElbow.x', 'rightElbow.y', 'rightElbow.score', 'leftWrist.x',
#        'leftWrist.y', 'leftWrist.score', 'rightWrist.x', 'rightWrist.y',
#        'rightWrist.score', 'leftHip.x', 'leftHip.y', 'leftHip.score',
#        'rightHip.x', 'rightHip.y', 'rightHip.score', 'leftKnee.x',
#        'leftKnee.y', 'leftKnee.score', 'rightKnee.x', 'rightKnee.y',
#        'rightKnee.score', 'leftAnkle.x', 'leftAnkle.y', 'leftAnkle.score',
#        'rightAnkle.x', 'rightAnkle.y', 'rightAnkle.score', 'shotType'],
#       dtype='object')

# %%
dataset.describe()
# Out:
#              score       nose.x       nose.y   nose.score    leftEye.x  \
# count  2242.000000  2242.000000  2242.000000  2242.000000  2242.000000
# mean      0.350284   105.305655    80.455046     0.404302   107.806336
# std       0.284007    44.697157    46.554271     0.373969    46.716310
# min       0.002546   -61.664287   -25.198069     0.000492   -58.788130
# 25%       0.066808    76.395935    50.614088     0.034106    79.593127
# 50%       0.313122   103.685968    73.933489     0.278290   107.199518
# 75%       0.598283   136.952888   109.102703     0.800129   140.591187
# max       0.957724   254.749200   303.466073     0.999871   204.972388
#
#          leftEye.y  leftEye.score   rightEye.x   rightEye.y  rightEye.score  \
# count  2242.000000    2242.000000  2242.000000  2242.000000     2242.000000
# mean     75.105956       0.369992   104.506647    74.965711        0.355604
# std      45.470875       0.359500    43.127540    46.053537        0.361510
# ...

# %%
# sns.pairplot(dataset, hue='shotType')

# %% [markdown]
# # Seperating out DataFrames

# %% [markdown]
# ## Dataframe of Scores

# %%
scores_df = dataset[['score', 'nose.score',
       'leftEye.score', 'rightEye.score',
       'leftEar.score',
       'rightEar.score',
       'leftShoulder.score',
       'rightShoulder.score', 'leftElbow.score',
       'rightElbow.score',
       'leftWrist.score',
       'rightWrist.score', 'leftHip.score',
       'rightHip.score',
       'leftKnee.score',
       'rightKnee.score','leftAnkle.score',
       'rightAnkle.score']]

# %%
scores_df.describe().iloc[:,:]
# Out:
#              score   nose.score  leftEye.score  rightEye.score  leftEar.score  \
# count  2242.000000  2242.000000    2242.000000     2242.000000    2242.000000
# mean      0.350284     0.404302       0.369992        0.355604       0.312443
# std       0.284007     0.373969       0.359500        0.361510       0.315737
# min       0.002546     0.000492       0.000485        0.000396       0.000526
# 25%       0.066808     0.034106       0.029244        0.025749       0.026883
# 50%       0.313122     0.278290       0.232019        0.193155       0.184488
# 75%       0.598283     0.800129       0.728687        0.694762       0.575556
# max       0.957724     0.999871       0.999777        0.999602       0.990906
#
#        rightEar.score  leftShoulder.score  rightShoulder.score  \
# count     2242.000000         2242.000000          2242.000000
# mean         0.235366            0.458337             0.440900
# std          0.274716            0.379667             0.383117
# ...

# %% [markdown]
# ## DataFrame of Coordinates

# %%
coordinates_df = dataset.drop(list(scores_df.columns), axis=1)

# %%
coordinates_df
# Out:
#           nose.x      nose.y   leftEye.x   leftEye.y  rightEye.x  rightEye.y  \
# 0     108.738780   47.988105  111.893715   46.692416  109.049632   48.145040
# 1     117.449880  102.737121  113.653701  106.626447  114.049373  107.309548
# 2     117.626733   45.139581  188.052499   79.762799   91.939183   -4.568707
# 3     144.697880   71.559764  148.007529   69.838149  139.243955   67.130005
# 4     234.872977   16.636874  162.790018    3.606339   36.423653   88.531245
# 5     142.681920   25.360366   79.952757   26.790548  149.024387    7.636763
# 6     108.900084   49.688167  111.695523   46.616729  109.398262   48.222838
# 7     123.309682   99.201930  125.807131   95.045177  130.381169   93.426564
# 8     156.038645   64.225757  158.999485   60.090125  152.409416   61.592806
# 9      98.367476    0.081173  103.203615   -3.087085   98.320132   -1.940384
# 10    125.229939   33.376598  127.590058   28.252898  123.469152   28.640358
# ...

# %%
sns.heatmap(coordinates_df.corr(), annot=True)

# %% [markdown]
# # Pre-Processing

# %%
raw_X = dataset.iloc[:, :-1]
y = dataset.iloc[:,-1]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(raw_X)

# %%
raw_X
# Out:
#          score      nose.x      nose.y  nose.score   leftEye.x   leftEye.y  \
# 0     0.442102  108.738780   47.988105    0.229462  111.893715   46.692416
# 1     0.063144  117.449880  102.737121    0.002066  113.653701  106.626447
# 2     0.034086  117.626733   45.139581    0.007047  188.052499   79.762799
# 3     0.494649  144.697880   71.559764    0.934364  148.007529   69.838149
# 4     0.008539  234.872977   16.636874    0.000705  162.790018    3.606339
# 5     0.334112  142.681920   25.360366    0.151952   79.952757   26.790548
# 6     0.489109  108.900084   49.688167    0.274101  111.695523   46.616729
# 7     0.453612  123.309682   99.201930    0.469616  125.807131   95.045177
# 8     0.460071  156.038645   64.225757    0.646617  158.999485   60.090125
# 9     0.626717   98.367476    0.081173    0.274828  103.203615   -3.087085
# 10    0.749078  125.229939   33.376598    0.802877  127.590058   28.252898
# ...

# %%
X
# Out:
# array([[ 0.32336666,  0.0768257 , -0.69755541, ...,  0.06367792,
#         -1.0775849 ,  1.52862202],
#        [-1.01125686,  0.27176078,  0.47873257, ...,  0.15153365,
#          0.64482777, -0.76097095],
#        [-1.11359353,  0.27571837, -0.75875622, ..., -0.7549625 ,
#         -3.33388861, -0.53086012],
#        ...,
#        [ 1.72525326,  1.2634535 , -0.21364231, ...,  0.51395099,
#         -0.13155175,  2.50563029],
#        [-0.32186546, -0.25549239,  0.18752969, ...,  0.20844179,
#          1.28829305, -0.79294412],
#        [-1.21401984,  1.60061027,  0.36179231, ...,  1.89577625,
#          1.03345165, -0.81854963]])

# %% [markdown]
# # Train & Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# # Start building out Neural Net Model

# %% [markdown]
# ## Importing Libraries: using Sequential model of keras

# %%
from keras import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
input_dim = X_train.shape[1]

# %%
input_dim
# Out:
# 52

# %% [markdown]
# ## Building Classifier

# %%
classifier = Sequential()

# %% [markdown]
# ### First Hidden Layer

# %%
classifier.add(Dense(input_dim//2, activation='relu', kernel_initializer='random_normal', input_dim=input_dim))

# %% [markdown]
# ### Second Hidden Layer

# %%
classifier.add(Dense(input_dim//8, activation='relu', kernel_initializer='random_normal'))

# %% [markdown]
# ### Output Layer

# %%
classifier.add(Dense(6, activation='sigmoid', kernel_initializer='random_normal'))

# %% [markdown]
# ## Compiling the Neural Network

# %%
classifier.compile(optimizer ='adam',loss='binary_crossentropy', metrics =['accuracy'])

# %% [markdown]
# ## Fitting the data to the training dataset

# %%
classifier.fit(X_train,y_train, batch_size=10, epochs=100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-72cbdf78b12a> in <module>
# ----> 1 classifier.fit(X_train,y_train, batch_size=10, epochs=100)
#
# ~/ml/Deep Learning/Deep-Learning-Basics/Implementations/Resuming ML Basics/Part 8 - Deep Learning/tempDLvenv/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     950             sample_weight=sample_weight,
#     951             class_weight=class_weight,
# --> 952             batch_size=batch_size)
#     953         # Prepare validation data.
#     954         do_validation = False
#
# ...
